# 38  0.000000      0.0  0.177419  0.311290  0.176613  0.143548  0.191129
# 39  0.000792      0.0  0.003167  0.053840  0.414885  0.003167  0.524149
# 40  0.000779      0.0  0.214174  0.054517  0.232087  0.007788  0.490654

# %%
y=df.loc[:, "enjoyed":]

# %%
y
# Out:
#     enjoyed
# 0         1
# 1         1
# 2         1
# 3         0
# 4         0
# 5         0
# 6         1
# 7         1
# 8         1
# 9         0
# 10        1
# 11        0
# 12        1
# 13        0
# 14        0
# 15        1
# 16        1
# 17        1
# 18        0
# 19        1
# 20        0
# 21        0
# 22        1
# 23        1
# 24        0
# 25        0
# 26        1
# 27        0
# 28        0
# 29        0
# 30        1
# 31        1
# 32        0
# 33        1
# 34        1
# 35        1
# 36        1
# 37        1
# 38        1
# 39        0
# 40        0

# %%
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2, random_state=20)

# %%
y_train.shape
# Out:
# (32, 1)

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
clf=AdaBoostClassifier(random_state=16)

# %%
clf.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=16)

# %%
clf.score(x_train ,y_train)
# Out:
# 1.0

# %%
clf.score(x_test, y_test)
# Out:
# 1.0

# %%
import cv2
from deepface import DeepFace

faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap= cv2.VideoCapture(-1)
if not cap.isOpened():
    cap=cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")

angry=0
disgust=0
fear=0
happy=0
sad=0
surprise=0
neutral=0
total=0

while True:
    ret,frame=cap.read()
    result=DeepFace.analyze(frame, actions=["emotion"],enforce_detection=False)
    
    gray=cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    faces=faceCascade.detectMultiScale(gray,1.1,4)
    
    for(x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w, y+h),(0,255,0),2)
        
    font=cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame,
            result["dominant_emotion"],
            (50,100),
            font, 3,
            (0,0,255),
            2,
            cv2.LINE_4
           )
    if(result["dominant_emotion"]=="angry"):
        angry=angry+1;
    elif(result["dominant_emotion"]=="disgust"):
        disgust=disgust+1;
    elif(result["dominant_emotion"]=="fear"):
        fear=fear+1;
    elif(result["dominant_emotion"]=="happy"):
        happy=happy+1;
    elif(result["dominant_emotion"]=="sad"):
        sad=sad+1;
    elif(result["dominant_emotion"]=="surprise"):
        surprise=surprise+1;
    elif(result["dominant_emotion"]=="neutral"):
        neutral=neutral+1;
    total=total+1
    if not ret:
        break
    cv2.imshow('asd', frame)
    cv2.waitKey(1)
    if cv2.getWindowProperty('asd', 4) < 1:
        break
cap.release()
cv2.destroyAllWindows()
ratios = [angry/total,disgust/total,fear/total,happy/total,sad/total,surprise/total,neutral/total,total]
other_arr = other_str.split(',')
types_arr=['action','comedy','drama','horror','romance']
types_num_arr=[0,1,0,0,0]
for i in range(len(types_arr)):
    for j in range(len(other_arr)):
        if(types_arr[i]==other_arr[j]):
            types_num_arr[i]=1
            break
            
ratios_plus_types=[angry/total,disgust/total,fear/total,happy/total,sad/total,surprise/total,neutral/total]
for i in range(len(types_num_arr)):
    ratios_plus_types.append(types_num_arr[i])
                   
ratios_plus_types.append(total)
ratios_plus_types.append(enj)
ratios.append(enj)   
ratios.pop()
ratios.pop()

temp=[ratios]
yhat = clf.predict(temp)
if(yhat[0]==1):
    print('Prediction: You enjoyed the movie')
else:
    print('Prediction: You did not enjoy the movie')
# Out:
# If you enjoyed the video, input 1, else type 0 :0
# If you would like to add in other types \(Such as
#  action,comedy,drama,horror,romance \) then
#  input them seperated with a "," :
# Prediction: You enjoyed the movie

# %%
temp=[[0.0005824111822947001,0.0,0.19394292370413513,0.3220733838089691,0.15433896330809552,0.1188118811881188,0.21025043680838673]]
yhat = clf.predict(temp)
if(yhat[0]==1):
    print('Prediction: You enjoyed the movie')
else:
    print('Prediction: You did not enjoy the movie')
# Out:
# Prediction: You enjoyed the movie
